# %%
# Importing libraries

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

get_ipython().run_line_magic('matplotlib', 'inline')
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

# Read in the data

df = pd.read_csv('/Users/saminkakatuwawala/Desktop/Data Analytics Project/Python Correlation Project/movies.csv')

# %%
# Looking at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#Drop nulls

df = df.dropna()

# Checking for nulls

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Data tyoes for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change datatype of column
df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  correctyear
# 0   699       46  19000000   46998772     1426    146.0         1980
# 1   214       47   4500000   58853106      452    104.0         1980
# 2  1157       47  18000000  538375067      945    124.0         1980
# 3  1474       47   3500000   83453539     1108     88.0         1980
# 4   271       47   6000000   39846344     1083     98.0         1980

# %%
df['correctyear'] = df['year']

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  correctyear
# 0   699       46  19000000   46998772     1426    146.0         1980
# 1   214       47   4500000   58853106      452    104.0         1980
# 2  1157       47  18000000  538375067      945    124.0         1980
# 3  1474       47   3500000   83453539     1108     88.0         1980
# 4   271       47   6000000   39846344     1083     98.0         1980

# %%
df.sort_values(by = ['gross'], inplace = False, ascending = False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
# dropping duplicates

df['company'].drop_duplicates().sort_values(ascending = False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
# scatter plot with budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings of Film')

plt.ylabel('Budget for Film')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plot budget vs gross thru seaborn

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {"color": "green"}, line_kws = {"color": "blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Compute the correlation matrix using pearson, kendall, and spearman
numeric_df.corr(method='pearson')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# correctyear  1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
#
#              correctyear
# year            1.000000
# score           0.056386
# votes           0.206021
# budget          0.327722
# gross           0.274321
# runtime         0.075077
# correctyear     1.000000

# %%
corr_matrix = numeric_df.corr(method='pearson')

sns.heatmap(corr_matrix, annot = True)

plt.title('Correlation Matrix for Float Values')

plt.xlabel('Features of Film')

plt.ylabel('Features of Film')

plt.show()

# %%
df_numrized = df

for col_name in df_numrized.columns:
    if(df_numrized[col_name].dtype == 'object'):
        df_numrized[col_name] = df_numrized[col_name].astype('category')
        df_numerized[col_name] = df_numrized[col_name].cat.codes

df_numrized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  correctyear
# 0   699       46  19000000   46998772     1426    146.0         1980
# 1   214       47   4500000   58853106      452    104.0         1980
# 2  1157       47  18000000  538375067      945    124.0         1980
# 3  1474       47   3500000   83453539     1108     88.0         1980
# 4   271       47   6000000   39846344     1083     98.0         1980

# %%
corr_matrix = df_numrized.corr(method='pearson')

sns.heatmap(corr_matrix, annot = True)

plt.title('Correlation Matrix for Float Values')

plt.xlabel('Features of Film')

plt.ylabel('Features of Film')

plt.show()

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#              score          0.014450
#              votes          0.012615
#              director       0.015246
#              writer         0.012880
#              star          -0.006882
#              country       -0.025490
#              budget         0.023392
#              gross          0.005639
#              company        0.021697
#              runtime        0.010850
#              correctyear    0.025542
# rating       name          -0.029234
#              rating         1.000000
#              genre          0.147796
#              year           0.019499
#              released       0.018083
#              score          0.065983
#              votes          0.006031
#              director       0.014656
#              writer        -0.003149
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
# budget       rating        -0.203946
# gross        rating        -0.181906
# rating       gross         -0.181906
# votes        genre         -0.135990
# genre        votes         -0.135990
# company      rating        -0.092357
# rating       company       -0.092357
# genre        correctyear   -0.073167
# year         genre         -0.073167
# genre        year          -0.073167
# correctyear  genre         -0.073167
# genre        company       -0.071334
# company      genre         -0.071334
# correctyear  country       -0.066748
# country      correctyear   -0.066748
#              year          -0.066748
# year         country       -0.066748
# runtime      genre         -0.059237
# genre        runtime       -0.059237
# country      score         -0.043051
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# correctyear  year           1.000000
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         correctyear    1.000000
#              year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# correctyear  correctyear    1.000000
# dtype: float64

# %%
# Budget has the highest correlalation to gross followed by votes
